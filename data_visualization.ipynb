# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
with open("reviews.json","r") as f:
    reviews_data = json.load(f)

print(len(reviews_data))
# Out:
# 2346

# %%
flattened_data = []
#for flattening the data of reviews to allow it to be stored in a data frame
for review in reviews_data:
    for key, details in review.items():
        #splitting review number
        review_number = int(key.split("_")[-1])
        #unpacking ratings dict into three values in 1 dict
        ratings = {rating_type: int(value) for rating in details["Ratings"] for rating_type, value in rating.items()}
        #appending it to the data
        flattened_data.append({
            "review_count": review_number,
            "overall": ratings.get("Overall", None),
            "food": ratings.get("Food", None),
            "service": ratings.get("Service", None),
            "ambience": ratings.get("Ambience", None),
            "date": details["Date"],
            "review": details["Review"]
        })

df_reviews = pd.DataFrame(flattened_data)
df_reviews
# Out:
#       review_count  overall  food  service  ambience  \
# 0                1        3     3        2         2
# 1                2        5     5        5         5
# 2                3        5     5        5         4
# 3                4        1     1        1         3
# 4                5        5     5        5         5
# ...            ...      ...   ...      ...       ...
# 2341          2342        5     5        4         4
# 2342          2343        4     5        4         4
# 2343          2344        1     3        3         2
# 2344          2345        4     4        4         3
# 2345          2346        3     3        3         2
#
#                             date  \
# 0     Dined on November 16, 2024
# 1      Dined on October 31, 2024
# 2       Dined on August 16, 2024
# 3         Dined on July 28, 2024
# 4         Dined on July 21, 2024
# ...                          ...
# 2341     Dined on April 26, 2009
# 2342     Dined on April 24, 2009
# ...

# %%
#count occurance of each overall rating and sort them
overall_dist = df_reviews["overall"].value_counts().sort_index()

#clean dataframe for plotting
overall_dist_df = overall_dist.reset_index()
overall_dist_df.columns = ["overall", "count"]

# Plotting the distribution
sns.barplot(data=overall_dist_df, x="count", y="overall", palette="viridis")
plt.title("Distribution of Overall Ratings")
plt.xlabel("Count")
plt.ylabel("Review Number (Overall Rating)")
plt.tight_layout()
#saving for showing in analysis tab of flask app
plt.savefig("./static/images/overall_rating_distribution.png")
plt.show()
# Out:
# C:\Users\Abdul Moiz\AppData\Local\Temp\ipykernel_16248\3695174731.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=overall_dist_df, x="count", y="overall", palette="viridis")

# %%
#count occurance of each overall rating and sort them
overall_dist = df_reviews["food"].value_counts().sort_index()

#clean dataframe for plotting
overall_dist_df = overall_dist.reset_index()
overall_dist_df.columns = ["food", "count"]

# Plotting the distribution
sns.barplot(data=overall_dist_df, x="count", y="food", palette="viridis")
plt.title("Distribution of Food Ratings")
plt.xlabel("Count")
plt.ylabel("Review Number (Food Rating)")
plt.tight_layout()
#saving for showing in analysis tab of flask app
plt.savefig("./static/images/food_rating_distribution.png")
plt.show()
# Out:
# C:\Users\Abdul Moiz\AppData\Local\Temp\ipykernel_16248\2769110202.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=overall_dist_df, x="count", y="food", palette="viridis")

# %%
#count occurance of each overall rating and sort them
overall_dist = df_reviews["service"].value_counts().sort_index()

#clean dataframe for plotting
overall_dist_df = overall_dist.reset_index()
overall_dist_df.columns = ["service", "count"]

# Plotting the distribution
sns.barplot(data=overall_dist_df, x="count", y="service", palette="viridis")
plt.title("Distribution of Service Ratings")
plt.xlabel("Count")
plt.ylabel("Review Number (Service Rating)")
plt.tight_layout()
#saving for showing in analysis tab of flask app
plt.savefig("./static/images/service_rating_distribution.png")
plt.show()
# Out:
# C:\Users\Abdul Moiz\AppData\Local\Temp\ipykernel_16248\3589764934.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=overall_dist_df, x="count", y="service", palette="viridis")

# %%
#count occurance of each overall rating and sort them
overall_dist = df_reviews["ambience"].value_counts().sort_index()

#clean dataframe for plotting
overall_dist_df = overall_dist.reset_index()
overall_dist_df.columns = ["ambience", "count"]

# Plotting the distribution
sns.barplot(data=overall_dist_df, x="count", y="ambience", palette="viridis")
plt.title("Distribution of Ambience Ratings")
plt.xlabel("Count")
plt.ylabel("Review Number (Ambience Rating)")
plt.tight_layout()
#saving for showing in analysis tab of flask app
plt.savefig("./static/images/ambience_rating_distribution.png")
plt.show()
# Out:
# C:\Users\Abdul Moiz\AppData\Local\Temp\ipykernel_16248\1637264187.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=overall_dist_df, x="count", y="ambience", palette="viridis")

# %%
with open("analysis.json","r") as f:
    comments_data = json.load(f)

print(len(comments_data))
# Out:
# 2081

# %%
df_comments = pd.DataFrame(comments_data)
df_comments
# Out:
#      Sentiment                                 Comment about food  \
# 0     negative                               not worth going back
# 1     positive  Wagyu skewers, beef noodle soup, hamachi, and ...
# 2     positive  beef noodle soup, wagyu, and uni were highligh...
# 3     negative                   Food choices seemed very limited
# 4      neutral                               no information given
# ...        ...                                                ...
# 2076  positive  the food was some of the best I've eaten in a ...
# 2077  positive                               no information given
# 2078  negative                               no information given
# 2079  positive  The porterhouse steak is wonderful. Hamachi sh...
# 2080   neutral  Wagyu A5 steaks are amazing with fatty flavors...
#
#                             Comment about staff/service  Review  \
# 0                                  no information given       1
# ...

# %%
df_comments = df_comments.dropna(axis=1)

# %%
df_comments
# Out:
#      Sentiment                                 Comment about food  \
# 0     negative                               not worth going back
# 1     positive  Wagyu skewers, beef noodle soup, hamachi, and ...
# 2     positive  beef noodle soup, wagyu, and uni were highligh...
# 3     negative                   Food choices seemed very limited
# 4      neutral                               no information given
# ...        ...                                                ...
# 2076  positive  the food was some of the best I've eaten in a ...
# 2077  positive                               no information given
# 2078  negative                               no information given
# 2079  positive  The porterhouse steak is wonderful. Hamachi sh...
# 2080   neutral  Wagyu A5 steaks are amazing with fatty flavors...
#
#                             Comment about staff/service  Review
# 0                                  no information given       1
# ...

# %%
#count sentiment values
sentiment_dist = df_comments["Sentiment"].value_counts().sort_index()

#convert series into a data frame
sentiment_dist = sentiment_dist.reset_index()

#rename the columns
sentiment_dist.columns = ["Sentiment", "Count"]

sns.barplot(data=sentiment_dist, x="Sentiment", y="Count", palette="viridis")
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.tight_layout()

plt.savefig("static/images/sentiment_distribution_bar.png")

plt.show()
# Out:
# C:\Users\Abdul Moiz\AppData\Local\Temp\ipykernel_16248\3460375439.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sentiment_dist, x="Sentiment", y="Count", palette="viridis")

# %%
#converts date column to string then replace Dined on with empty string and converts the date to datetime objects of pandas
df_reviews["date"] = pd.to_datetime(df_reviews["date"].astype(str).str.replace("Dined on ", "", regex=False))

#groups reviews by date converted into periods of years, gets its count and reset index to create review_count column
popularity_yearly = df_reviews.groupby(df_reviews["date"].dt.to_period("Y")).size().reset_index(name="review_count")

#converting the periods (2024) back to time stamps (2024-01-01 00:00:00)
popularity_yearly["date"] = popularity_yearly["date"].dt.to_timestamp()

plt.figure(figsize=(12, 9))
plt.plot(popularity_yearly["date"], popularity_yearly["review_count"], marker="o", linestyle="-", color="blue")
plt.title("Restaurant Popularity Over Time (Yearly Aggregated)", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("Number of Reviews", fontsize=14)
plt.grid(visible=True, linestyle="--", alpha=0.7)
plt.tight_layout()

plt.savefig("static/images/popularity_over_time_yearly.png")
plt.show()
